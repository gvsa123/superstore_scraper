# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from functools import reduce
from datetime import datetime

# %%
In [6]: df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'), index=None)

# %%
NOW = datetime.now()
DATE = NOW.strftime("%m-%d-%Y")

# %%
df['A'] = DATE

# %%
df['A']
# Out:
# 0      05-02-2020
# 1      05-02-2020
# 2      05-02-2020
# 3      05-02-2020
# 4      05-02-2020
#           ...
# 995    05-02-2020
# 996    05-02-2020
# 997    05-02-2020
# 998    05-02-2020
# 999    05-02-2020
# Name: A, Length: 1000, dtype: object

# %%
df.cumsum().plot()
